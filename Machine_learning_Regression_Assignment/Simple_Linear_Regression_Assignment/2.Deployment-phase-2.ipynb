# %%
#Importing pickle module to load the model
import pickle

# %%
#Load the model from the file
loaded_data = pickle.load(open("finalized_model_linear.sav",'rb'))

# %%
#Predict the output based on input
result = loaded_data.predict([[15]])
print("Predicted value: \n", result)
# Out:
# Predicted value:
#  [[167181.3106341]]
# C:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
