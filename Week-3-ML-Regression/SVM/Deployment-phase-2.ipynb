# %%
import pickle

# %%
filename = "finalized_model_svm.sav"
loaded_model = pickle.load(open(filename, 'rb'))

# %%
result = loaded_model.predict([[1234,345,4565,1,0]])
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([43211.6321245])
