# %%
import pickle
filename = "finalized_model_random_forest_regression.sav"
loaded_model = pickle.load(open(filename,'rb'))
model_output = loaded_model.predict([[987,7878,399,1,0]])
model_output
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([47799.7606])
